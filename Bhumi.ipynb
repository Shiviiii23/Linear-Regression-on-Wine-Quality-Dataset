# %% [markdown]
# <a href="https://colab.research.google.com/github/Shiviiii23/Linear-Regression-on-Wine-Quality-Dataset/blob/master/Bhumi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyroSAR
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 60.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.0/43.0 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.29
#     Uninstalling SQLAlchemy-2.0.29:
#       Successfully uninstalled SQLAlchemy-2.0.29
# ...

# %%
pip install git+https://github.com/johntruckenbrodt/pyroSAR.git
# Out:
# ...
#   Cloning https://github.com/johntruckenbrodt/pyroSAR.git to /tmp/pip-req-build-iwvd3cc6
#   Running command git clone --filter=blob:none --quiet https://github.com/johntruckenbrodt/pyroSAR.git /tmp/pip-req-build-iwvd3cc6
#   Resolved https://github.com/johntruckenbrodt/pyroSAR.git to commit f1b4f500888458e104d02a1e2627b8aa3226b48f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for pyroSAR: filename=pyroSAR-0.24.1.dev12+gf1b4f50-py3-none-any.whl size=4820014 sha256=d5ed3d70a505c51e98fad3d851c70aab182ef724770cd138f3e343f77fa9738e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-4t44agvy/wheels/f5/5f/a3/26661b46b0e72953629545898a6425ea109cf3ae0a5cf63bb0
# Successfully built pyroSAR
# ...
#   Attempting uninstall: pyroSAR
#     Found existing installation: pyroSAR 0.24.0
#     Uninstalling pyroSAR-0.24.0:
#       Successfully uninstalled pyroSAR-0.24.0
# ...

# %%
# !pip install gdal

# %%
from osgeo import gdal

# %%
# !apt-get install libsqlite3-mod-spatialite
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   libsqlite3-mod-spatialite
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 2,097 kB of archives.
# After this operation, 8,524 kB of additional disk space will be used.
# Get:1 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 libsqlite3-mod-spatialite amd64 5.0.1-3~jammy0 [2,097 kB]
# Fetched 2,097 kB in 2s (1,214 kB/s)
# Selecting previously unselected package libsqlite3-mod-spatialite:amd64.
# (Reading database ... 121752 files and directories currently installed.)
# Preparing to unpack .../libsqlite3-mod-spatialite_5.0.1-3~jammy0_amd64.deb ...
# Unpacking libsqlite3-mod-spatialite:amd64 (5.0.1-3~jammy0) ...
# Setting up libsqlite3-mod-spatialite:amd64 (5.0.1-3~jammy0) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# ...

# %%
from pyroSAR import identify

# %%
pip install asf_search
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.7/90.7 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 9.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.2.3
#     Uninstalling tenacity-8.2.3:
#       Successfully uninstalled tenacity-8.2.3
# ...

# %%
import asf_search as asf

results = asf.granule_search(['ALPSRS279162400', 'ALPSRS279162200'])
print(results)

wkt = 'POLYGON((-135.7 58.2,-136.6 58.1,-135.8 56.9,-134.6 56.1,-134.9 58.0,-135.7 58.2))'
results = asf.geo_search(platform=[asf.PLATFORM.SENTINEL1], intersectsWith=wkt, maxResults=10)
print(results)
# Out:
# {
#   "features": [
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -144.207,
#               61.899
#             ],
#             [
#               -145.235,
#               58.851
#             ],
#             [
#               -139.288,
#               58.195
#             ],
#             [
#               -137.7,
#               61.211
#             ],
#             [
#               -144.207,
#               61.899
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "WB1",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/A3/ALPSRS279162400.jpg"
#         ],
#         "bytes": 23900540,
#         "centerLat": 60.077,
#         "centerLon": -141.6007,
#         "faradayRotation": 5.605801,
#         "fileID": "ALPSRS279162400-L1.5",
#         "fileName": "ALPSRS279162400-L1.5.zip",
# ...
